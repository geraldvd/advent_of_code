# %% [markdown]
# # Day 23 (2023-12-23), Exercise a

# %%
with open("input_23_dummy.txt", "r") as fh:
    lines = fh.readlines()
# Remove \n characters
lines = [l.strip() for l in lines]
assert len(lines) == len(lines[0]), "Assuming square grid"

# %%
import numpy as np

# %%
lines
def create_grid_dict(lines):
    grid_dict = {}
    for i in len(lines):
        for j in len(lines):
            grid_dict[(i,j)] = {
            'visited': False,
            }
# Out:
# ['#.#####################',
#  '#.......#########...###',
#  '#######.#########.#.###',
#  '###.....#.>.>.###.#.###',
#  '###v#####.#v#.###.#.###',
#  '###.>...#.#.#.....#...#',
#  '###v###.#.#.#########.#',
#  '###...#.#.#.......#...#',
#  '#####.#.#.#######.#.###',
#  '#.....#.#.#.......#...#',
#  '#.#####.#.#.#########v#',
#  '#.#...#...#...###...>.#',
#  '#.#.#v#######v###.###v#',
#  '#...#.>.#...>.>.#.###.#',
#  '#####v#.#.###v#.#.###.#',
#  '#.....#...#...#.#.#...#',
#  '#.#########.###.#.#.###',
#  '#...###...#...#...#.###',
#  '###.###.#.###v#####v###',
#  '#...#...#.#.>.>.#.>.###',
#  '#.###.###.#.###.#.#v###',
#  '#.....###...###...#...#',
#  '#####################.#']

# %% [markdown]
# # Day 23 (2023-12-23), Exercise b
